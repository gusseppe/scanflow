# %%
import os

root = os.getcwd()
root
# Out:
# '/home/guess/Desktop/inference/vision/classification_and_detection'

# %%
# !tools/make_fake_imagenet.sh

# %%
import os
os.environ['MODEL_DIR'] = os.path.join(root, 'models')
os.environ['DATA_DIR'] = os.path.join(root, "fake_imagenet")
os.environ['EXTRA_OPS'] ="--samples-per-query 20 --time 10 --max-latency 0.2 --accuracy"

# %%
# !du . -sh
# Out:
# 110M	.

# %%
# !./run_and_time.sh tensorflow mobilenet cpu
# Out:
# Sending build context to Docker daemon  104.1MB
# Step 1/14 : FROM ubuntu:16.04
#  ---> c871c45b1573
# Step 2/14 : ENV PYTHON_VERSION=3.7
#  ---> Using cache
#  ---> d6a31a95d5ce
# Step 3/14 : ENV LANG C.UTF-8
#  ---> Using cache
#  ---> 5e5b17cae872
# Step 4/14 : ENV LC_ALL C.UTF-8
#  ---> Using cache
#  ---> 0bef428e0b5e
# Step 5/14 : ENV PATH /opt/anaconda3/bin:$PATH
#  ---> Using cache
#  ---> 2082e4530296
# Step 6/14 : WORKDIR /root
#  ---> Using cache
#  ---> 75e4b569f56c
# Step 7/14 : ENV HOME /root
#  ---> Using cache
#  ---> 65cc2921b793
# Step 8/14 : RUN apt-get update && apt-get install -y --no-install-recommends       git       build-essential       software-properties-common       ca-certificates       wget       curl       htop       zip       unzip
#  ---> Running in 02cdb6b5c76a
# Get:1 http://archive.ubuntu.com/ubuntu xenial InRelease [247 kB]
# Get:2 http://security.ubuntu.com/ubuntu xenial-security InRelease [109 kB]
# ...

# %%
# !./run_docker.sh tf resnet50 cpu
# Out:
# Clearing caches.
# 3
# STARTING RUN AT 2020-09-27 07:23:04 PM
# INFO:main:Namespace(accuracy=True, backend='tensorflow', cache=0, count=None, data_format=None, dataset='imagenet', dataset_list=None, dataset_path='/home/guess/Desktop/inference/vision/classification_and_detection/fake_imagenet', find_peak_performance=False, inputs=['input_tensor:0'], max_batchsize=32, max_latency=0.2, mlperf_conf='./mlperf.conf', model='/home/guess/Desktop/inference/vision/classification_and_detection/models/resnet50_v1.pb', model_name='resnet50', output='/output', outputs=['ArgMax:0'], profile='resnet50-tf', qps=None, samples_per_query=20, scenario='SingleStream', threads=4, time=10, user_conf='user.conf')
# 2020-09-27 19:23:05.578178: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# ...

# %%
# # !./run_common.sh tf
# !echo $(./run_common.sh; echo $%s)

# os.environ["backend"]
